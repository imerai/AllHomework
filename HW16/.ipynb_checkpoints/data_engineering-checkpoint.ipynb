# %%
# Add dependencies
import glob
import pandas as pd

# %%
# glob.glob('data*.csv') - returns List[str]
# pd.read_csv(f) - returns pd.DataFrame()
# for f in glob.glob() - returns a List[DataFrames]
# pd.concat() - returns one pd.DataFrame()
clean_data_ridership = pd.concat([pd.read_csv(f) for f in glob.glob('raw_data/CitiBikeDailyRidershipandMembershipData/*.csv')], ignore_index = True)

# %%
clean_data_ridership.head()
# Out:
#      Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  1/1/17                                              16009
# 1  1/2/17                                               8921
# 2  1/3/17                                              14198
# 3  1/4/17                                              34039
# 4  1/5/17                                              28393
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        50761
# 1                                        21545
# 2                                        25879
# 3                                        69966
# 4                                        52446
#
#    Total Annual Members (All Time)  \
# 0                           206624
# 1                           206675
# 2                           206728
# 3                           206778
# 4                           206845
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
# clean_data_trip = pd.concat([pd.read_csv(f) for f in glob.glob('raw_data/CitiBikeTripHistories/*.csv')],  sort=True)
df1 = pd.read_csv('raw_data/CitiBikeTripHistories/JC-201701-citibike-tripdata.csv')
df1.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            148  2017-01-01 00:21:32  2017-01-01 00:24:01              3276
# 1           1283  2017-01-01 00:24:35  2017-01-01 00:45:58              3183
# 2            372  2017-01-01 00:38:19  2017-01-01 00:44:31              3183
# 3           1513  2017-01-01 00:38:37  2017-01-01 01:03:50              3194
# 4            639  2017-01-01 01:47:52  2017-01-01 01:58:31              3183
#
#   Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0   Marin Light Rail               40.714584               -74.042817
# 1     Exchange Place               40.716247               -74.033459
# 2     Exchange Place               40.716247               -74.033459
# 3    McGinley Square               40.725340               -74.067622
# 4     Exchange Place               40.716247               -74.033459
#
#    End Station ID     End Station Name  End Station Latitude  \
# ...

# %%
# df1.rename(columns = {'Trip Duration': 'tripduration', 'Start Time': 'starttime', 
#                       'Stop Time': 'stoptime', 'Gender':'gender', "User Type": "usertype",
#                       'Bike ID': 'bikeid', 'Birth Year': 'birth year', 'Start Station ID': 'start station id',
#                       'Start Station Name': 'start station name', 'Start Station Latitude': 'start station latitude',
#                       'Start Station Longitude': 'start station longitude', 'End Station ID': 'end station id', 
#                       'End Station Name': 'end station name', 'End Station Latitude': 'end station latitude',
#                       'End Station Longitude': 'end station longitude'}, inplace = True)
# df1.head()

# %%
df2 = pd.read_csv('raw_data/CitiBikeTripHistories/JC-201702-citibike-tripdata.csv')
df2.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            435  2017-02-01 00:06:33  2017-02-01 00:13:49              3214
# 1            779  2017-02-01 01:02:21  2017-02-01 01:15:21              3194
# 2            145  2017-02-01 01:56:05  2017-02-01 01:58:30              3211
# 3            184  2017-02-01 04:38:42  2017-02-01 04:41:46              3276
# 4            197  2017-02-01 04:42:22  2017-02-01 04:45:39              3214
#
#   Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0   Essex Light Rail               40.712774               -74.036486
# 1    McGinley Square               40.725340               -74.067622
# 2         Newark Ave               40.721525               -74.046305
# 3   Marin Light Rail               40.714584               -74.042817
# 4   Essex Light Rail               40.712774               -74.036486
#
#    End Station ID      End Station Name  End Station Latitude  \
# ...

# %%
# clean_data_trip.head()

# %%
df3 = pd.read_csv('raw_data/CitiBikeTripHistories/JC-201703-citibike-tripdata.csv')
df3.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0           1076  2017-03-01 00:03:02  2017-03-01 00:20:58              3275
# 1            978  2017-03-01 00:09:02  2017-03-01 00:25:20              3220
# 2           1789  2017-03-01 00:28:11  2017-03-01 00:58:00              3195
# 3            613  2017-03-01 00:52:30  2017-03-01 01:02:44              3194
# 4           2418  2017-03-01 00:54:40  2017-03-01 01:34:59              3199
#
#   Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0     Columbus Drive               40.718355               -74.038914
# 1  5 Corners Library               40.734961               -74.059503
# 2            Sip Ave               40.730743               -74.063784
# 3    McGinley Square               40.725340               -74.067622
# 4       Newport Pkwy               40.728745               -74.032108
#
#    End Station ID      End Station Name  End Station Latitude  \
# ...

# %%
df4 = pd.read_csv('raw_data/CitiBikeTripHistories/JC-201704-citibike-tripdata.csv')
df4.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           252  2017-04-01 00:14:36  2017-04-01 00:18:48              3186
# 1           452  2017-04-01 00:15:47  2017-04-01 00:23:20              3203
# 2           465  2017-04-01 00:46:27  2017-04-01 00:54:13              3271
# 3           417  2017-04-01 00:47:15  2017-04-01 00:54:13              3271
# 4           391  2017-04-01 01:13:12  2017-04-01 01:19:44              3183
#
#     start station name  start station latitude  start station longitude  \
# 0        Grove St PATH               40.719586               -74.043117
# 1        Hamilton Park               40.727596               -74.044247
# 2  Danforth Light Rail               40.692640               -74.088012
# 3  Danforth Light Rail               40.692640               -74.088012
# 4       Exchange Place               40.716247               -74.033459
#
#    end station id end station name  end station latitude  \
# ...

# %%
df5 = pd.read_csv('raw_data/CitiBikeTripHistories/JC-201705-citibike-tripdata.csv')
df5.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           347  2017-05-01 00:03:19  2017-05-01 00:09:06              3276
# 1           108  2017-05-01 00:16:04  2017-05-01 00:17:53              3275
# 2           165  2017-05-01 00:29:59  2017-05-01 00:32:44              3267
# 3           289  2017-05-01 00:30:47  2017-05-01 00:35:36              3209
# 4           115  2017-05-01 00:41:14  2017-05-01 00:43:09              3185
#
#   start station name  start station latitude  start station longitude  \
# 0   Marin Light Rail               40.714584               -74.042817
# 1     Columbus Drive               40.718355               -74.038914
# 2       Morris Canal               40.712419               -74.038526
# 3       Brunswick St               40.724176               -74.050656
# 4          City Hall               40.717733               -74.043845
#
#    end station id   end station name  end station latitude  \
# ...

# %%
df6 = pd.read_csv('raw_data/CitiBikeTripHistories/JC-201706-citibike-tripdata.csv')
df6.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           499  2017-06-01 00:01:39  2017-06-01 00:09:59              3195
# 1           507  2017-06-01 00:06:39  2017-06-01 00:15:07              3211
# 2           768  2017-06-01 00:44:43  2017-06-01 00:57:31              3195
# 3           101  2017-06-01 01:12:55  2017-06-01 01:14:36              3185
# 4           265  2017-06-01 01:14:00  2017-06-01 01:18:25              3273
#
#   start station name  start station latitude  start station longitude  \
# 0            Sip Ave               40.730743               -74.063784
# 1         Newark Ave               40.721525               -74.046305
# 2            Sip Ave               40.730743               -74.063784
# 3          City Hall               40.717733               -74.043845
# 4       Manila & 1st               40.721651               -74.042884
#
#    end station id         end station name  end station latitude  \
# ...

# %%
df7 = pd.read_csv('raw_data/CitiBikeTripHistories/JC-201707-citibike-tripdata.csv')
df7.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           340  2017-07-01 00:00:08  2017-07-01 00:05:48              3186
# 1           439  2017-07-01 00:02:35  2017-07-01 00:09:55              3183
# 2           186  2017-07-01 00:04:33  2017-07-01 00:07:40              3186
# 3           442  2017-07-01 00:05:53  2017-07-01 00:13:15              3195
# 4           170  2017-07-01 00:07:54  2017-07-01 00:10:45              3187
#
#   start station name  start station latitude  start station longitude  \
# 0      Grove St PATH               40.719586               -74.043117
# 1     Exchange Place               40.716247               -74.033459
# 2      Grove St PATH               40.719586               -74.043117
# 3            Sip Ave               40.730743               -74.063784
# 4          Warren St               40.721124               -74.038051
#
#    end station id end station name  end station latitude  \
# ...

# %%
df8 = pd.read_csv('raw_data/CitiBikeTripHistories/JC-201708-citibike-tripdata.csv')
df8.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0          1314  2017-08-01 00:03:05  2017-08-01 00:24:59              3187
# 1           221  2017-08-01 00:06:25  2017-08-01 00:10:06              3213
# 2           185  2017-08-01 00:42:28  2017-08-01 00:45:33              3211
# 3            72  2017-08-01 00:45:06  2017-08-01 00:46:18              3269
# 4           499  2017-08-01 01:12:10  2017-08-01 01:20:30              3185
#
#   start station name  start station latitude  start station longitude  \
# 0          Warren St               40.721124               -74.038051
# 1     Van Vorst Park               40.718489               -74.047727
# 2         Newark Ave               40.721525               -74.046305
# 3    Brunswick & 6th               40.726012               -74.050389
# 4          City Hall               40.717733               -74.043845
#
#    end station id end station name  end station latitude  \
# ...

# %%
df9 = pd.read_csv('raw_data/CitiBikeTripHistories/JC-201709-citibike-tripdata.csv')
df9.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           364  2017-09-01 00:02:01  2017-09-01 00:08:05              3183
# 1           357  2017-09-01 00:08:12  2017-09-01 00:14:09              3187
# 2           432  2017-09-01 00:10:12  2017-09-01 00:17:24              3195
# 3           934  2017-09-01 00:10:11  2017-09-01 00:25:46              3272
# 4           932  2017-09-01 00:10:16  2017-09-01 00:25:48              3272
#
#   start station name  start station latitude  start station longitude  \
# 0     Exchange Place               40.716247               -74.033459
# 1          Warren St               40.721124               -74.038051
# 2            Sip Ave               40.730743               -74.063784
# 3       Jersey & 3rd               40.723332               -74.045953
# 4       Jersey & 3rd               40.723332               -74.045953
#
#    end station id  end station name  end station latitude  \
# ...

# %%
df10 = pd.read_csv('raw_data/CitiBikeTripHistories/JC-201710-citibike-tripdata.csv')
df10.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           410  2017-10-01 00:03:08  2017-10-01 00:09:59              3213
# 1           412  2017-10-01 00:03:13  2017-10-01 00:10:06              3213
# 2           274  2017-10-01 00:24:07  2017-10-01 00:28:42              3195
# 3          2198  2017-10-01 00:31:03  2017-10-01 01:07:42              3199
# 4           166  2017-10-01 00:34:09  2017-10-01 00:36:56              3186
#
#   start station name  start station latitude  start station longitude  \
# 0     Van Vorst Park               40.718489               -74.047727
# 1     Van Vorst Park               40.718489               -74.047727
# 2            Sip Ave               40.730743               -74.063784
# 3       Newport Pkwy               40.728745               -74.032108
# 4      Grove St PATH               40.719586               -74.043117
#
#    end station id    end station name  end station latitude  \
# ...

# %%
df11 = pd.read_csv('raw_data/CitiBikeTripHistories/JC-201711-citibike-tripdata.csv')
df11.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           370  2017-11-01 00:04:26  2017-11-01 00:10:37              3199
# 1            96  2017-11-01 00:05:45  2017-11-01 00:07:22              3211
# 2            73  2017-11-01 00:09:49  2017-11-01 00:11:03              3275
# 3           162  2017-11-01 00:14:04  2017-11-01 00:16:47              3275
# 4           214  2017-11-01 00:23:38  2017-11-01 00:27:13              3276
#
#   start station name  start station latitude  start station longitude  \
# 0       Newport Pkwy               40.728745               -74.032108
# 1         Newark Ave               40.721525               -74.046305
# 2     Columbus Drive               40.718355               -74.038914
# 3     Columbus Drive               40.718355               -74.038914
# 4   Marin Light Rail               40.714584               -74.042817
#
#    end station id end station name  end station latitude  \
# ...

# %%
df12 = pd.read_csv('raw_data/CitiBikeTripHistories/JC-201712-citibike-tripdata.csv')
df12.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           452  2017-12-01 00:00:59  2017-12-01 00:08:32              3183
# 1           159  2017-12-01 00:04:42  2017-12-01 00:07:21              3187
# 2           175  2017-12-01 00:17:00  2017-12-01 00:19:55              3186
# 3           455  2017-12-01 00:50:22  2017-12-01 00:57:57              3194
# 4           670  2017-12-01 00:55:03  2017-12-01 01:06:13              3194
#
#   start station name  start station latitude  start station longitude  \
# 0     Exchange Place               40.716247               -74.033459
# 1          Warren St               40.721124               -74.038051
# 2      Grove St PATH               40.719586               -74.043117
# 3    McGinley Square               40.725340               -74.067622
# 4    McGinley Square               40.725340               -74.067622
#
#    end station id      end station name  end station latitude  \
# ...

# %%
citibike_2017 = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12])
citibike_2017
# Out:
# C:\Users\VINESH\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   """Entry point for launching an IPython kernel.
#        Bike ID  Birth Year  End Station ID  End Station Latitude  \
# 0      24575.0      1983.0          3185.0             40.717733
# 1      24723.0      1978.0          3198.0             40.748716
# 2      24620.0      1989.0          3211.0             40.721525
# 3      24668.0      1961.0          3271.0             40.692640
# 4      26167.0      1993.0          3203.0             40.727596
# 5      24604.0      1970.0          3270.0             40.725289
# 6      24641.0      1978.0          3206.0             40.731169
# ...

# %%
citibike_2017.to_csv('clean_data/citibike_2017.csv', sep = ',')

# %%
clean_data_trip.count()
# Out:
# Bike ID                     39153
# Birth Year                  37448
# End Station ID              39153
# End Station Latitude        39153
# End Station Longitude       39153
# End Station Name            39153
# Gender                      39153
# Start Station ID            39153
# Start Station Latitude      39153
# Start Station Longitude     39153
# Start Station Name          39153
# Start Time                  39153
# Stop Time                   39153
# Trip Duration               39153
# User Type                   39036
# bikeid                     255775
# birth year                 237865
# end station id             255775
# end station latitude       255775
# end station longitude      255775
# end station name           255775
# gender                     255775
# start station id           255775
# start station latitude     255775
# start station longitude    255775
# start station name         255775
# starttime                  255775
# ...

# %%
# Export to csv
clean_data_ridership.to_csv("clean_data/clean_quarter_data_2017.csv")
clean_data_trip.to_csv("clean_data/clean_data_2017.csv")
